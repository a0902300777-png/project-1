# %% [markdown]
# <a href="https://colab.research.google.com/github/a0902300777-png/project-1/blob/main/411402879_%E9%99%B3%E4%BA%91%E9%88%9E.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#單一車輛辨識車牌號碼：
# 安裝套件
# !pip install ultralytics easyocr -q
import cv2
import matplotlib.pyplot as plt
from ultralytics import YOLO
import easyocr
# 載入 YOLO 模型
model = YOLO("yolov8n.pt")
# OCR
reader = easyocr.Reader(['en'])
img_path = "car_1.jpg"
img = cv2.imread(img_path)
# YOLO 偵測
results = model(img_path)
# 處理偵測結果
for r in results:
    for box in r.boxes:
        # 座標
        x1, y1, x2, y2 = map(int, box.xyxy[0])
        # 裁切區域
        crop = img[y1:y2, x1:x2]
        # OCR 辨識
        ocr_result = reader.readtext(crop)
        text = ""
        for t in ocr_result:
            text += t[1] + " "
        text = text.strip()
        # 有辨識到文字才畫框
        if text != "":
            # 畫框
            cv2.rectangle(
                img,
                (x1, y1),
                (x2, y2),
                (0, 255, 0),
                2
            )
            # 顯示文字
            cv2.putText(
                img,
                text,
                (x1, y1 - 10),
                cv2.FONT_HERSHEY_SIMPLEX,
                0.9,
                (0, 255, 0),
                2
            )

            print("車牌辨識結果：", text)
# BGR → RGB
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(12,8))
plt.imshow(img_rgb)
plt.axis("off")
# Out:
# WARNING:easyocr.easyocr:Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_414/1385189002.py in <cell line: 0>()
#      13 img = cv2.imread(img_path)
#      14 # YOLO 偵測
# ---> 15 results = model(img_path)
#      16 # 處理偵測結果
#      17 for r in results:
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py in __call__(self, source, stream, **kwargs)
#     175             ...     print(f"Detected {len(r)} objects in image")
#     176         """
# --> 177         return self.predict(source, stream, **kwargs)
#     178
#     179     @staticmethod
#
# /usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py in predict(self, source, stream, predictor, **kwargs)
# ...
